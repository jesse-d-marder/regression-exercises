# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from scipy import stats

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr, spearmanr

from env import get_db_url
import wrangle
import explore

# %%
query = """SELECT * FROM customers;"""
df = pd.read_sql(query, get_db_url('mall_customers'))

# %%
df.head()
# Out:
#    customer_id  gender  age  annual_income  spending_score
# 0            1    Male   19             15              39
# 1            2    Male   21             15              81
# 2            3  Female   20             16               6
# 3            4  Female   23             16              77
# 4            5  Female   31             17              40

# %%
df.dtypes
# Out:
# customer_id        int64
# gender            object
# age                int64
# annual_income      int64
# spending_score     int64
# dtype: object

# %%
categorical = ['gender']
continuous = ['age','annual_income','spending_score']

# %%
explore.plot_categorical_and_continuous_vars(df, categorical, continuous, len(df))
# Out:
# Generating plots age by gender
# Generating plots annual_income by gender
# Generating plots spending_score by gender

# %% [markdown]
# ### Takeaways:
#  - Wider range in ages for males vs females
#  - Annual income median slightly higher for males vs females
#  - Spending score about equal or higher for females vs males

# %%
sns.lmplot(data=df, x='annual_income', y='spending_score', hue=None)
